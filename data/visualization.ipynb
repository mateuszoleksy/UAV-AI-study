# %% [markdown]
# Import required libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas
import os

# %% [markdown]
# Load proccesed data:

# %%
absolute_path = os.getcwd()
filename = "vehicle_local_position.csv"

dataset = pd.read_csv(absolute_path + "/processed/" + filename)

# %% [markdown]
# Let's jump to the visualizations, first begin with heatmap:

# %%
# 1. Calculate the correlation matrix
corr_matrix = dataset.corr()

# 2. Plot the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Histogram and scatter:

# %%
sns.pairplot(dataset)

# %% [markdown]
# Histogram for every column:

# %%
for column in dataset.select_dtypes(include=['number']).columns:
    plt.figure(figsize=(8, 4))      # Create a new "canvas" for each plot
    sns.histplot(dataset[column], kde=True) # kde=True adds a smooth trend line
    plt.title(f'Distribution of {column}')
    plt.show()                      # Show the plot and clear the canvas for the next one

# %% [markdown]
# Boxplot:

# %%
for column in dataset.select_dtypes(include=['number']).columns:
    plt.figure(figsize=(8, 2)) # Boxplots are often better "wide"
    sns.boxplot(x=dataset[column])
    plt.title(f'Outliers in {column}')
    plt.show()

# %% [markdown]
# Desribe (max, min, deviation):

# %%
dataset.describe()
# Out:
#        Unnamed: 0           x           y           z          vx          vy  \
# count  217.000000  217.000000  217.000000  217.000000  217.000000  217.000000
# mean   108.000000   -5.715945   -1.904972   -6.678318   -0.031805   -0.027059
# std     62.786676    0.254247    0.299912    0.823141    0.047627    0.067194
# min      0.000000   -6.131155   -2.364568   -8.154167   -0.107349   -0.139063
# 25%     54.000000   -5.883837   -2.146068   -7.304230   -0.077076   -0.084660
# 50%    108.000000   -5.779947   -2.010317   -6.752205   -0.032321   -0.017080
# 75%    162.000000   -5.413698   -1.587203   -5.999626   -0.000430    0.026556
# max    216.000000   -5.271250   -1.330531   -5.172440    0.081360    0.079080
#
#                vz          ax          ay          az     heading   timestamp
# count  217.000000  217.000000  217.000000  217.000000  217.000000  217.000000
# mean     0.058587    0.052249   -0.057771    0.023829   -2.716783   10.790925
# ...

# %% [markdown]
# Violinplot:

# %%
sns.violinplot(dataset)
# Out:
# <Axes: >

# %% [markdown]
# To be described...
